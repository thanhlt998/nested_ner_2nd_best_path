# %%
# !nvidia-smi
# Out:
# Mon Dec 28 12:29:28 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    24W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/models/nested_ner/2nd_best_path_1
# Out:
# /content/drive/MyDrive/models/nested_ner/2nd_best_path_1

# %%
# !git clone https://github.com/thanhlt998/nested_ner_2nd_best_path
# Out:
# Cloning into 'nested_ner_2nd_best_path'...
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 61 (delta 24), reused 52 (delta 15), pack-reused 0
# Unpacking objects: 100% (61/61), done.

# %%
# %cd nested_ner_2nd_best_path
# Out:
# /content/drive/My Drive/models/nested_ner/2nd_best_path_1/nested_ner_2nd_best_path

# %%
# !wget -O data.zip https://husteduvn-my.sharepoint.com/:u:/g/personal/thanh_lt163705_sis_hust_edu_vn/Ef6M4YANvaJAhEFCwwF8a4IB4V4ui5a7Lf6MBOk-op5pSw?download=1
# !unzip data.zip

# %%
# !pip install transformers adabound stanfordnlp

# %%
# !git pull origin master

# %%
# !python -W ignore train.py
# Out:
# 2020-12-28 17:16:53.626788: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# ...
